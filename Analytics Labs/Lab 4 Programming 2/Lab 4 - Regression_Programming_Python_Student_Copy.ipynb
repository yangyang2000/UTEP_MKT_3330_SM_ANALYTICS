# %% [markdown]
# # This lab will guide you through some data oriented programming tasks
#
# 1. Read in datasets
# 2. Manipulating data
# 3. Merging Datasets
# 4. Groupby Summaries
# 5. Run Regressions
#
# **Write comments for all your code, if you don't comment your code in this class, you will not get credit on your assignments**

# %% [markdown]
# ## 1. Read in the following dataset and display the first and last 5 rows
#
# ```python
# 'https://www.dropbox.com/s/yjo0ri1mph6we52/properties_2016_small.csv?dl=1'
# ```

# %%
import pandas as pd # reads in the pandas module renames as pd
df = pd.read_csv('https://www.dropbox.com/s/yjo0ri1mph6we52/properties_2016_small.csv?dl=1', index_col = 0) # read the csv file, call it df

# %%
df.head()
# Out:
#          parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 234813   14209488                    NaN                       NaN
# 2520413  12423712                    NaN                       NaN
# 758283   14677098                    1.0                       NaN
# 733400   11694391                    NaN                       NaN
# 1044816  11511529                    NaN                       NaN
#
#          basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 234813            NaN          2.0         3.0                  NaN
# 2520413           NaN          1.0         4.0                  NaN
# 758283            NaN          2.0         3.0                  NaN
# 733400            NaN          3.0         6.0                  NaN
# 1044816           NaN          1.0         1.0                  NaN
#
#          buildingqualitytypeid  calculatedbathnbr  decktypeid  \
# 234813                     NaN                2.0         NaN
# 2520413                    7.0                1.0         NaN
# 758283                     NaN                2.0         NaN
# 733400                     4.0                3.0         NaN
# 1044816                    4.0                1.0         NaN
#
#                 ...           numberofstories  fireplaceflag  \
# 234813          ...                       1.0            NaN
# 2520413         ...                       NaN            NaN
# 758283          ...                       1.0           True
# 733400          ...                       NaN            NaN
# 1044816         ...                       NaN            NaN
#
#          structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 234813                      94407.0           397519.0          2015.0
# 2520413                     25885.0            41973.0          2015.0
# 758283                     126287.0           370448.0          2015.0
# 733400                     107401.0           277095.0          2015.0
# 1044816                     68214.0           164993.0          2015.0
#
#          landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# 234813                303112.0    4515.14                 NaN
# 2520413                16088.0     786.08                 NaN
# 758283                244161.0    3892.34                 NaN
# 733400                169694.0    3559.08                 NaN
# 1044816                96779.0    1988.57                 NaN
#
#          taxdelinquencyyear  censustractandblock
# 234813                  NaN         6.059022e+13
# 2520413                 NaN         6.037555e+13
# 758283                  NaN                  NaN
# 733400                  NaN         6.037233e+13
# 1044816                 NaN         6.037621e+13
#
# [5 rows x 58 columns]

# %%
df.tail()
# Out:
#          parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 230262   12390638                    1.0                       NaN
# 519850   14737127                    NaN                       NaN
# 1797187  14307201                    NaN                       NaN
# 1870728  14146252                    NaN                       NaN
# 1975066  14244037                   13.0                       NaN
#
#          basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 230262            NaN          3.0         4.0                  NaN
# 519850            NaN          1.0         2.0                  NaN
# 1797187           NaN          3.0         5.0                  NaN
# 1870728           NaN          2.5         3.0                  NaN
# 1975066           NaN          2.5         4.0                  NaN
#
#          buildingqualitytypeid  calculatedbathnbr  decktypeid  \
# 230262                     7.0                3.0         NaN
# 519850                     NaN                1.0         NaN
# 1797187                    NaN                3.0         NaN
# 1870728                    NaN                2.5         NaN
# 1975066                    NaN                2.5         NaN
#
#                 ...           numberofstories  fireplaceflag  \
# 230262          ...                       NaN            NaN
# 519850          ...                       NaN            NaN
# 1797187         ...                       1.0            NaN
# 1870728         ...                       2.0            NaN
# 1975066         ...                       2.0            NaN
#
#          structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 230262                     140902.0           164127.0          2015.0
# 519850                     130964.0           264272.0          2015.0
# 1797187                    161017.0           389475.0          2015.0
# 1870728                    101727.0           165684.0          2015.0
# 1975066                    250561.0           644090.0          2015.0
#
#          landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# 230262                 23225.0    2540.68                 NaN
# 519850                133308.0    3104.28                 NaN
# 1797187               228458.0    4213.06                 NaN
# 1870728                63957.0    2099.24                 NaN
# 1975066               393529.0    7103.82                 NaN
#
#          taxdelinquencyyear  censustractandblock
# 230262                  NaN         6.037501e+13
# 519850                  NaN         6.059052e+13
# 1797187                 NaN         6.059053e+13
# 1870728                 NaN         6.059002e+13
# 1975066                 NaN         6.059076e+13
#
# [5 rows x 58 columns]

# %% [markdown]
# # 2. Manipulating the dataset
#
# 1. List all the columns of the dataset.
# 2. Display the unique values for the variable `poolcnt`.
# 3. Replace all the `nan` in `poolcnt` with 0. you can use the replace function (Google pandas replace). Note that `nan` is the numpy version of `None` and it is called by importing numpy:
# ```python
# import numpy as np # import numpy module
# np.nan # np.nan gives you the nan value, this is the value you want to replace with 0
# ```
# 4. What data type is stored in the variable yearbuilt? Change it to int. Note you have to first replace np.nan with None, then change to integer. Use the "`map`" function on the column series df.yearbuilt. `.map` maps any function to the values in that function. What function did you map to conver to interger type?
# 5. Plot a scatterplot of the longitude and latitude. Note that Longitude corresponds to x-axis and latitude corresponds to the y axis. Remember to import pyplot and make the plots inline:
# ```python
# % matplotlib inline
# import matplotlib.pyplot as plt
# ```
# Make the plot using the plt.scatter function. Play around with the `c`, `s`, and `alpha` parameters.
# 6. For each cohort year (`yearbuilt`), plot the distribution of assessed value of the homes (`taxvaluedollarcnt`) for 2 bedroom homes. Note you can do histograms by selecting just the data that you need and appending the `.hist()` function. You should use a loop to loop through all the unique years. Plot the histogram inside the loop. To ensure you have a different figure for each plot, use the `plt.figure()` before plotting. Remember before you loop through all the years, you should make sure to not include `nan` years and to sort years from smallest to largest, you can do this using the `sorted` function.
# ```python
# # write code to create listofuniqueyears
# # make sure this list of years does not include nan values and is sorted
# for year in listofuniqueyears: # note you have have to define listofuniqueyears
#         plt.figure()
#         plt.title(year) # this sets the title for the plot
#         # code to select data and plot histogram
# ```
# 7. Create a second dataframe using all the squarefeet variables (any variable that contains squarefeet) and parcelid. Drop *just* the squarefeet variables from the original dataframe. Display all the columns of these 2 dataframes

# %% [markdown]
# # 1. List all the columns

# %%
df.columns.values
# Out:
# array(['parcelid', 'airconditioningtypeid', 'architecturalstyletypeid',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingclasstypeid',
#        'buildingqualitytypeid', 'calculatedbathnbr', 'decktypeid',
#        'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'finishedsquarefeet13',
#        'finishedsquarefeet15', 'finishedsquarefeet50',
#        'finishedsquarefeet6', 'fips', 'fireplacecnt', 'fullbathcnt',
#        'garagecarcnt', 'garagetotalsqft', 'hashottuborspa',
#        'heatingorsystemtypeid', 'latitude', 'longitude',
#        'lotsizesquarefeet', 'poolcnt', 'poolsizesum', 'pooltypeid10',
#        'pooltypeid2', 'pooltypeid7', 'propertycountylandusecode',
#        'propertylandusetypeid', 'propertyzoningdesc',
#        'rawcensustractandblock', 'regionidcity', 'regionidcounty',
#        'regionidneighborhood', 'regionidzip', 'roomcnt', 'storytypeid',
#        'threequarterbathnbr', 'typeconstructiontypeid', 'unitcnt',
#        'yardbuildingsqft17', 'yardbuildingsqft26', 'yearbuilt',
#        'numberofstories', 'fireplaceflag', 'structuretaxvaluedollarcnt',
#        'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt',
#        'taxamount', 'taxdelinquencyflag', 'taxdelinquencyyear',
#        'censustractandblock'], dtype=object)

# %% [markdown]
# # 2. Display unique values of `poolcnt`

# %%
df.poolcnt.unique()
# Out:
# array([ nan,   1.])

# %% [markdown]
# # 3. Replace `nan`'s with 0's

# %%
import numpy as np # import numpy library as np
df.poolcnt.replace(np.nan,0, inplace = True) # replace poolcnt nan values with 0, change the column in place

# %%
df.poolcnt.unique() # look at new unique values
# Out:
# array([ 0.,  1.])

# %% [markdown]
# # 4. Change yearbuilt from float to integers

# %%
df.yearbuilt.replace(np.nan, None, inplace = True) # replace nan's with None's so you can do the code below
df.yearbuilt = df.yearbuilt.map(int) # maps functin "int" to each row of df.yearbuilt

# %%
# df.yearbuilt

# %% [markdown]
# # 5. Scatterplot of longitude/latitude

# %%
% matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.scatter(df.longitude, df.latitude, s = 1, c='red', alpha = .05)

# %% [markdown]
# # 6. Plot distribution of 2bdrm prices for each cohort of built years.

# %%
years = sorted(df.loc[~df.yearbuilt.isnull(), 'yearbuilt'].unique())

# %%
for y in years:
    plt.figure()
    plt.title(str(y))
    df.loc[(df.yearbuilt==y)&(df.bedroomcnt == 2), 'taxvaluedollarcnt'].hist()
# Out:
# C:\Users\yangy\AppData\Local\conda\conda\envs\py27\lib\site-packages\matplotlib\pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# # 7. Create a new dataframe including only `squarefeet` and `parcelid` columns, drop these from original dataframe

# %%
columnstokeep = [c for c in df.columns.values if 'squarefeet' in c] +['parcelid']
columnstokeep
# Out:
# ['finishedfloor1squarefeet',
#  'calculatedfinishedsquarefeet',
#  'finishedsquarefeet12',
#  'finishedsquarefeet13',
#  'finishedsquarefeet15',
#  'finishedsquarefeet50',
#  'finishedsquarefeet6',
#  'lotsizesquarefeet',
#  'parcelid']

# %%
# df[columnstokeep]

# %%
columnstokeep = [c for c in df.columns.values if 'squarefeet' in c] +['parcelid'] # create list of columns
df2 = df[columnstokeep] # create new dataframe with only columnstokeep
df.drop([c for c in df.columns.values if 'squarefeet' in c], axis = 1, inplace = True) # drop sqft columns

# %%
df2.columns.values
# Out:
# array(['finishedfloor1squarefeet', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'finishedsquarefeet13',
#        'finishedsquarefeet15', 'finishedsquarefeet50',
#        'finishedsquarefeet6', 'lotsizesquarefeet', 'parcelid'], dtype=object)

# %%
df.columns.values
# Out:
# array(['parcelid', 'airconditioningtypeid', 'architecturalstyletypeid',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingclasstypeid',
#        'buildingqualitytypeid', 'calculatedbathnbr', 'decktypeid', 'fips',
#        'fireplacecnt', 'fullbathcnt', 'garagecarcnt', 'garagetotalsqft',
#        'hashottuborspa', 'heatingorsystemtypeid', 'latitude', 'longitude',
#        'poolcnt', 'poolsizesum', 'pooltypeid10', 'pooltypeid2',
#        'pooltypeid7', 'propertycountylandusecode', 'propertylandusetypeid',
#        'propertyzoningdesc', 'rawcensustractandblock', 'regionidcity',
#        'regionidcounty', 'regionidneighborhood', 'regionidzip', 'roomcnt',
#        'storytypeid', 'threequarterbathnbr', 'typeconstructiontypeid',
#        'unitcnt', 'yardbuildingsqft17', 'yardbuildingsqft26', 'yearbuilt',
#        'numberofstories', 'fireplaceflag', 'structuretaxvaluedollarcnt',
#        'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt',
#        'taxamount', 'taxdelinquencyflag', 'taxdelinquencyyear',
#        'censustractandblock'], dtype=object)

# %% [markdown]
# # Merge a dataset
#
# Merge these two datasets back together. What kind of merge should you use, ('inner', 'outer', 'left'), why? On what variable should you evaluate the merge? (what to merge on?)

# %%
df = df.merge(df2, how = 'left', on = 'parcelid')

# %%
df.columns.values
# Out:
# array(['parcelid', 'airconditioningtypeid', 'architecturalstyletypeid',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingclasstypeid',
#        'buildingqualitytypeid', 'calculatedbathnbr', 'decktypeid', 'fips',
#        'fireplacecnt', 'fullbathcnt', 'garagecarcnt', 'garagetotalsqft',
#        'hashottuborspa', 'heatingorsystemtypeid', 'latitude', 'longitude',
#        'poolcnt', 'poolsizesum', 'pooltypeid10', 'pooltypeid2',
#        'pooltypeid7', 'propertycountylandusecode', 'propertylandusetypeid',
#        'propertyzoningdesc', 'rawcensustractandblock', 'regionidcity',
#        'regionidcounty', 'regionidneighborhood', 'regionidzip', 'roomcnt',
#        'storytypeid', 'threequarterbathnbr', 'typeconstructiontypeid',
#        'unitcnt', 'yardbuildingsqft17', 'yardbuildingsqft26', 'yearbuilt',
#        'numberofstories', 'fireplaceflag', 'structuretaxvaluedollarcnt',
#        'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt',
#        'taxamount', 'taxdelinquencyflag', 'taxdelinquencyyear',
#        'censustractandblock', 'finishedfloor1squarefeet',
#        'calculatedfinishedsquarefeet', 'finishedsquarefeet12',
#        'finishedsquarefeet13', 'finishedsquarefeet15',
#        'finishedsquarefeet50', 'finishedsquarefeet6', 'lotsizesquarefeet'], dtype=object)

# %% [markdown]
# # Groupby
#
# 1. Use groupby to compute the average number of bedrooms in each cohort year, plot this as a line plot
# 2. Use groupby to compute the average number of bathrooms in each cohort year, plot this as a line plot
# 3. Use groupby to compute the average total sqft (`calculatedfinishedsquarefeet`), plot this as a line plot
# 4. Use groupby to compute the number of houses in each cohort year, plot this as a line plot
#
# Are there any interesting trends for these plots?

# %% [markdown]
# # Regression
# $$
# Value=\beta_0+\beta_1Sqft+\beta_{2,bdrm}+\beta_{3,bath}
# $$
# 1. Run the above regression. Note $\beta_{2,bdrm}$ and $\beta_{3,bath}$ means a separate coffecient for each level of bedroom and bathroom. This means you should treat the variables as a categorical variable:
# 2. Run the above regression separately for each cohort year. Store the coefficient of squarefootage for each regression in a list (see construction below). Plot the line plot of the coefficients vs. years.
# ```python
# sqft_coefficients = list()
# for y in years:
#          sqft_coefficients.append(yourcoefficient)
# ```
