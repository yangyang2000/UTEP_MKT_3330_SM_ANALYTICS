# %% [markdown]
# # Pandas details + Statsmodels + Matplotlib
#
# In this lecture, we will go over some common Pandas examples and go over how to run a linear regression using the package Statsmodels.

# %% [markdown]
# # Reading/Saving datasets
#
# We will read in Zillow's house price dataset (a small version of it)

# %%
import pandas as pd

# %% [markdown]
# ## This is for CSV

# %%
df = pd.read_csv('./data/Zillow/properties_2016_small.csv', index_col=0)
df = df.sample(n =50000)

# %% [markdown]
# ## We can save/read Excel files

# %%
# df.to_excel('./data/Zillow/properties_2016_small.xlsx') # this is really slow!

# %%
df = pd.read_excel('./data/Zillow/properties_2016_small.xlsx')
df.head()

# %% [markdown]
# ## We can save/read JSON files
#
# JSON are serialized data. This is like a Python dictionary format. Every data point is given a variable label. Every row is given an index.

# %%
# df.to_json('./data/Zillow/properties_2016_small.json')

# %%
df = pd.read_json('./data/Zillow/properties_2016_small.json')
df.head()
# Out:
#          airconditioningtypeid  architecturalstyletypeid  assessmentyear  \
# 1000010                    NaN                       NaN            2015
# 1000104                    NaN                       NaN            2015
# 1000127                    NaN                       NaN            2015
# 1000176                    NaN                       NaN            2015
# 1000262                    NaN                       NaN            2015
#
#          basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 1000010           NaN          4.0           8                  NaN
# 1000104           NaN          1.0           3                  NaN
# 1000127           NaN          2.0           2                  NaN
# 1000176           NaN          2.0           3                  NaN
# 1000262           NaN          1.0           2                  NaN
#
#          buildingqualitytypeid  calculatedbathnbr  \
# 1000010                    NaN                4.0
# 1000104                    7.0                1.0
# 1000127                    7.0                2.0
# 1000176                    7.0                2.0
# 1000262                    7.0                1.0
#
#          calculatedfinishedsquarefeet    ...      taxamount  \
# 1000010                        4011.0    ...        9061.52
# 1000104                         891.0    ...        1269.13
# 1000127                        1128.0    ...        2040.16
# 1000176                        1026.0    ...         999.41
# 1000262                         916.0    ...        8996.86
#
#          taxdelinquencyflag  taxdelinquencyyear  taxvaluedollarcnt  \
# 1000010                None                 NaN           632387.0
# 1000104                None                 NaN            55842.0
# 1000127                None                 NaN           160523.0
# 1000176                None                 NaN            50338.0
# 1000262                None                 NaN           729285.0
#
#          threequarterbathnbr  typeconstructiontypeid  unitcnt  \
# 1000010                  NaN                     NaN      4.0
# 1000104                  NaN                     NaN      1.0
# 1000127                  NaN                     NaN      1.0
# 1000176                  NaN                     NaN      1.0
# 1000262                  NaN                     NaN      1.0
#
#          yardbuildingsqft17  yardbuildingsqft26  yearbuilt
# 1000010                 NaN                 NaN     1959.0
# 1000104                 NaN                 NaN     1949.0
# 1000127                 NaN                 NaN     1984.0
# 1000176                 NaN                 NaN     1965.0
# 1000262                 NaN                 NaN     1950.0
#
# [5 rows x 58 columns]

# %%
df.shape
# Out:
# (90150, 58)

# %%
df.describe() # summary of data, computes descriptives for each quantitative column
# Out:
#            parcelid  airconditioningtypeid  architecturalstyletypeid  \
# count  9.015000e+04           28748.000000                260.000000
# mean   1.298488e+07               1.815222                  7.230769
# std    2.505517e+06               2.972108                  2.721397
# min    1.071174e+07               1.000000                  2.000000
# 25%    1.155970e+07               1.000000                  7.000000
# 50%    1.254744e+07               1.000000                  7.000000
# 75%    1.422757e+07               1.000000                  7.000000
# max    1.629608e+08              13.000000                 21.000000
#
#        basementsqft   bathroomcnt    bedroomcnt  buildingclasstypeid  \
# count     43.000000  90150.000000  90150.000000                 16.0
# mean     713.581395      2.279545      3.031936                  4.0
# std      437.434198      1.004133      1.156114                  0.0
# min      100.000000      0.000000      0.000000                  4.0
# 25%      407.500000      2.000000      2.000000                  4.0
# 50%      616.000000      2.000000      3.000000                  4.0
# 75%      872.000000      3.000000      4.000000                  4.0
# max     1555.000000     20.000000     16.000000                  4.0
#
#        buildingqualitytypeid  calculatedbathnbr  decktypeid  \
# count           57284.000000       88974.000000       658.0
# mean                5.565393           2.309175        66.0
# std                 1.900443           0.976137         0.0
# min                 1.000000           1.000000        66.0
# 25%                 4.000000           2.000000        66.0
# 50%                 7.000000           2.000000        66.0
# 75%                 7.000000           3.000000        66.0
# max                12.000000          20.000000        66.0
#
#               ...           yardbuildingsqft26     yearbuilt  numberofstories  \
# count         ...                    95.000000  89397.000000     20540.000000
# mean          ...                   311.694737   1968.539761         1.440798
# std           ...                   346.354850     23.763165         0.544482
# min           ...                    18.000000   1885.000000         1.000000
# 25%           ...                   100.000000   1953.000000         1.000000
# 50%           ...                   159.000000   1970.000000         1.000000
# 75%           ...                   361.000000   1987.000000         2.000000
# max           ...                  1366.000000   2015.000000         4.000000
#
#        structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# count                8.977200e+04       9.014900e+04         90150.0
# mean                 1.801032e+05       4.576379e+05          2015.0
# std                  2.090769e+05       5.548532e+05             0.0
# min                  1.000000e+02       2.200000e+01          2015.0
# 25%                  8.127175e+04       1.990560e+05          2015.0
# 50%                  1.320570e+05       3.429310e+05          2015.0
# 75%                  2.105380e+05       5.405890e+05          2015.0
# max                  9.948100e+06       2.775000e+07          2015.0
#
#        landtaxvaluedollarcnt      taxamount  taxdelinquencyyear  \
# count           9.014900e+04   90144.000000         1775.000000
# mean            2.782879e+05    5983.070888           13.401690
# std             4.005040e+05    6838.506814            2.720397
# min             2.200000e+01      49.080000            6.000000
# 25%             8.228500e+04    2873.260000           13.000000
# 50%             1.930000e+05    4543.100000           14.000000
# 75%             3.453840e+05    6900.165000           15.000000
# max             2.450000e+07  321936.090000           99.000000
#
#        censustractandblock
# count         8.954700e+04
# mean          6.049153e+13
# std           2.046987e+11
# min           6.037101e+13
# 25%           6.037320e+13
# 50%           6.037610e+13
# 75%           6.059042e+13
# max           6.111009e+13
#
# [8 rows x 53 columns]

# %% [markdown]
# # Slicing and dicing a dataset
#
# Notice that the index column doesn't start at 0, like a normal dataset, because this small dataset was taken from a larger dataset and the index columns were kept.

# %%
df[:10] # while this still works
# Out:
#      parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 362  17073783                    NaN                       NaN           NaN
# 428  17088994                    NaN                       NaN           NaN
# 470  17100444                    NaN                       NaN           NaN
# 480  17102429                    NaN                       NaN           NaN
# 507  17109604                    NaN                       NaN           NaN
# 555  17125829                    NaN                       NaN           NaN
# 570  17132911                    NaN                       NaN           NaN
# 580  17134926                    NaN                       NaN           NaN
# 605  17139988                    NaN                       NaN           NaN
# 719  17167359                    NaN                       NaN           NaN
#
#      bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 362          2.5         3.0                  NaN                    NaN
# 428          1.0         2.0                  NaN                    NaN
# 470          2.0         3.0                  NaN                    NaN
# 480          1.5         2.0                  NaN                    NaN
# 507          2.5         4.0                  NaN                    NaN
# 555          2.5         4.0                  NaN                    NaN
# 570          2.0         3.0                  NaN                    NaN
# 580          2.5         5.0                  NaN                    NaN
# 605          2.0         3.0                  NaN                    NaN
# 719          1.0         3.0                  NaN                    NaN
#
#      calculatedbathnbr  decktypeid         ...           numberofstories  \
# 362                2.5         NaN         ...                       2.0
# 428                1.0         NaN         ...                       1.0
# 470                2.0         NaN         ...                       1.0
# 480                1.5         NaN         ...                       1.0
# 507                2.5         NaN         ...                       2.0
# 555                2.5        66.0         ...                       2.0
# 570                2.0         NaN         ...                       1.0
# 580                2.5         NaN         ...                       2.0
# 605                2.0         NaN         ...                       1.0
# 719                1.0         NaN         ...                       1.0
#
#      fireplaceflag  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 362            NaN                    115087.0           191811.0
# 428            NaN                    143809.0           239679.0
# 470            NaN                     33619.0            47853.0
# 480            NaN                     45609.0            62914.0
# 507            NaN                    277000.0           554000.0
# 555            NaN                    222070.0           289609.0
# 570            NaN                    185000.0           526000.0
# 580            NaN                    342611.0           571086.0
# 605            NaN                    231297.0           462594.0
# 719            NaN                    134251.0           268502.0
#
#      assessmentyear  landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# 362          2015.0                76724.0    2015.06                 NaN
# 428          2015.0                95870.0    2581.30                 NaN
# 470          2015.0                14234.0     591.64                 NaN
# 480          2015.0                17305.0     682.78                 NaN
# 507          2015.0               277000.0    5886.92                 NaN
# 555          2015.0                67539.0    3110.44                 NaN
# 570          2015.0               341000.0    5632.20                 NaN
# 580          2015.0               228475.0    6109.94                 NaN
# 605          2015.0               231297.0    5026.40                 NaN
# 719          2015.0               134251.0    3217.06                 NaN
#
#      taxdelinquencyyear  censustractandblock
# 362                 NaN         6.111002e+13
# 428                 NaN         6.111002e+13
# 470                 NaN         6.111001e+13
# 480                 NaN         6.111001e+13
# 507                 NaN         6.111001e+13
# 555                 NaN         6.111005e+13
# 570                 NaN         6.111006e+13
# 580                 NaN         6.111006e+13
# 605                 NaN         6.111005e+13
# 719                 NaN         6.111004e+13
#
# [10 rows x 58 columns]

# %%
df.loc[:10,:] # this does not (the row index 0-10 do not exist)
# Out:
# Empty DataFrame
# Columns: [parcelid, airconditioningtypeid, architecturalstyletypeid, basementsqft, bathroomcnt, bedroomcnt, buildingclasstypeid, buildingqualitytypeid, calculatedbathnbr, decktypeid, finishedfloor1squarefeet, calculatedfinishedsquarefeet, finishedsquarefeet12, finishedsquarefeet13, finishedsquarefeet15, finishedsquarefeet50, finishedsquarefeet6, fips, fireplacecnt, fullbathcnt, garagecarcnt, garagetotalsqft, hashottuborspa, heatingorsystemtypeid, latitude, longitude, lotsizesquarefeet, poolcnt, poolsizesum, pooltypeid10, pooltypeid2, pooltypeid7, propertycountylandusecode, propertylandusetypeid, propertyzoningdesc, rawcensustractandblock, regionidcity, regionidcounty, regionidneighborhood, regionidzip, roomcnt, storytypeid, threequarterbathnbr, typeconstructiontypeid, unitcnt, yardbuildingsqft17, yardbuildingsqft26, yearbuilt, numberofstories, fireplaceflag, structuretaxvaluedollarcnt, taxvaluedollarcnt, assessmentyear, landtaxvaluedollarcnt, taxamount, taxdelinquencyflag, taxdelinquencyyear, censustractandblock]
# Index: []
#
# [0 rows x 58 columns]

# %% [markdown]
# We can fix this indexing by resetting the index and dropping the old index.

# %%
df.reset_index(inplace = True) # inplace means it saves the change in the variable df
df.head()
# Out:
#    index  parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0    362  17073783                    NaN                       NaN
# 1    428  17088994                    NaN                       NaN
# 2    470  17100444                    NaN                       NaN
# 3    480  17102429                    NaN                       NaN
# 4    507  17109604                    NaN                       NaN
#
#    basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0           NaN          2.5         3.0                  NaN
# 1           NaN          1.0         2.0                  NaN
# 2           NaN          2.0         3.0                  NaN
# 3           NaN          1.5         2.0                  NaN
# 4           NaN          2.5         4.0                  NaN
#
#    buildingqualitytypeid  calculatedbathnbr         ...           \
# 0                    NaN                2.5         ...
# 1                    NaN                1.0         ...
# 2                    NaN                2.0         ...
# 3                    NaN                1.5         ...
# 4                    NaN                2.5         ...
#
#    numberofstories  fireplaceflag  structuretaxvaluedollarcnt  \
# 0              2.0            NaN                    115087.0
# 1              1.0            NaN                    143809.0
# 2              1.0            NaN                     33619.0
# 3              1.0            NaN                     45609.0
# 4              2.0            NaN                    277000.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0           191811.0          2015.0                76724.0    2015.06
# 1           239679.0          2015.0                95870.0    2581.30
# 2            47853.0          2015.0                14234.0     591.64
# 3            62914.0          2015.0                17305.0     682.78
# 4           554000.0          2015.0               277000.0    5886.92
#
#    taxdelinquencyflag  taxdelinquencyyear  censustractandblock
# 0                 NaN                 NaN         6.111002e+13
# 1                 NaN                 NaN         6.111002e+13
# 2                 NaN                 NaN         6.111001e+13
# 3                 NaN                 NaN         6.111001e+13
# 4                 NaN                 NaN         6.111001e+13
#
# [5 rows x 59 columns]

# %%
df.drop(['index'], axis = 1, inplace = True) # drops the old index which is now a column named 'index'

# %%
df.reset_index().drop('index', axis = 1, inplace = True) # this would have worked as well
# but place the inplace argument in the last function's inputs

# %%
df.columns.values
# Out:
# array(['parcelid', 'airconditioningtypeid', 'architecturalstyletypeid',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingclasstypeid',
#        'buildingqualitytypeid', 'calculatedbathnbr', 'decktypeid',
#        'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'finishedsquarefeet13',
#        'finishedsquarefeet15', 'finishedsquarefeet50',
#        'finishedsquarefeet6', 'fips', 'fireplacecnt', 'fullbathcnt',
#        'garagecarcnt', 'garagetotalsqft', 'hashottuborspa',
#        'heatingorsystemtypeid', 'latitude', 'longitude',
#        'lotsizesquarefeet', 'poolcnt', 'poolsizesum', 'pooltypeid10',
#        'pooltypeid2', 'pooltypeid7', 'propertycountylandusecode',
#        'propertylandusetypeid', 'propertyzoningdesc',
#        'rawcensustractandblock', 'regionidcity', 'regionidcounty',
#        'regionidneighborhood', 'regionidzip', 'roomcnt', 'storytypeid',
#        'threequarterbathnbr', 'typeconstructiontypeid', 'unitcnt',
#        'yardbuildingsqft17', 'yardbuildingsqft26', 'yearbuilt',
#        'numberofstories', 'fireplaceflag', 'structuretaxvaluedollarcnt',
#        'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt',
#        'taxamount', 'taxdelinquencyflag', 'taxdelinquencyyear',
#        'censustractandblock'], dtype=object)

# %% [markdown]
# How many properties are there? How many have a pool?

# %%
len(df) # len returns number of rows
# Out:
# 90150

# %%
df.poolcnt.unique() # let's look at the possible values for variable poolcnt
# Out:
# array([ nan,   1.])

# %%
temp = df[~df.poolcnt.isnull()] # select all the cells for which ~df.poolcnt.isnull() is True
# ~df.poolcnt.isnull() returns True if poolcnt is NOT a null value (no data)
# The ~ "tilde" negates the boolean df.poolcnt.isnull()
len(temp), len(df[df.poolcnt.isnull()]) # we didn't need to create a new variable temp to do this
# Out:
# (17876, 72274)

# %% [markdown]
# How many have a pool and at least 3 bathrooms?

# %%
len(df[(df.poolcnt.isnull())&(df.bathroomcnt<=2)]) # pool is not null + and bathroomcnt>=3
# Out:
# 45785

# %% [markdown]
# Show the columns roomcnt and taxvaluedollarcnt for the 10 highest tax value homes in the dataset that has no pools and 4 bathrooms.

# %%
df.loc[(df.poolcnt.isnull())&(df.bathroomcnt==4), 
       ['bedroomcnt','taxvaluedollarcnt']].sort_values(
    by='taxvaluedollarcnt', ascending = False)[:10]

# we can break the code into a few lines by hitting enter after a comma in the code
# look at with this does
# First, we used .loc to slice the data for the no pools and 4 bathrooms conditions 
# We also select the appropriate columns to keep in the .loc index
# Next we used .sort_values to sort the data
# We sort by "taxvaluedollarcnt"
# We specify ascending=False, so that we sort from largest to smallest
# finally, with the sorted dataframe, we select the first 10 rows
# Out:
#        bedroomcnt  taxvaluedollarcnt
# 25283         6.0         11793518.0
# 29359         3.0          9594043.0
# 12325         6.0          6823665.0
# 28165         3.0          6209815.0
# 29987         4.0          6015000.0
# 89855         2.0          5409930.0
# 61735         4.0          5357428.0
# 19512         4.0          5037879.0
# 2797          3.0          4968623.0
# 20597         4.0          4845087.0

# %% [markdown]
# # Groupby summaries

# %% [markdown]
# What is the average tax value for every room count?

# %%
df.groupby('bedroomcnt')['taxvaluedollarcnt'].mean().sort_values()
# Out:
# bedroomcnt
# 1.0     2.662176e+05
# 14.0    2.795353e+05
# 2.0     3.423988e+05
# 15.0    3.624400e+05
# 3.0     4.115027e+05
# 0.0     4.277274e+05
# 13.0    5.010210e+05
# 10.0    5.418905e+05
# 4.0     5.494448e+05
# 12.0    6.058624e+05
# 11.0    7.296716e+05
# 8.0     7.318377e+05
# 9.0     8.033035e+05
# 5.0     8.589491e+05
# 16.0    8.857515e+05
# 6.0     1.108667e+06
# 7.0     1.554016e+06
# Name: taxvaluedollarcnt, dtype: float64

# %% [markdown]
# Let's plot this?

# %%
% matplotlib inline 
# majic that allows plots to be displayed in notebook
from matplotlib import pyplot as plt # import the plotting library

# %%
df.groupby('bedroomcnt')['taxvaluedollarcnt'].mean().plot(kind = 'bar') # using pandas' support for plt

# %%
temp = df.groupby('bedroomcnt')['taxvaluedollarcnt'].mean().reset_index()
temp
# Out:
#     bedroomcnt  taxvaluedollarcnt
# 0          0.0       4.277274e+05
# 1          1.0       2.662176e+05
# 2          2.0       3.423988e+05
# 3          3.0       4.115027e+05
# 4          4.0       5.494448e+05
# 5          5.0       8.589491e+05
# 6          6.0       1.108667e+06
# 7          7.0       1.554016e+06
# 8          8.0       7.318377e+05
# 9          9.0       8.033035e+05
# 10        10.0       5.418905e+05
# 11        11.0       7.296716e+05
# 12        12.0       6.058624e+05
# 13        13.0       5.010210e+05
# 14        14.0       2.795353e+05
# 15        15.0       3.624400e+05
# 16        16.0       8.857515e+05

# %%
plt.bar(temp.bedroomcnt, temp.taxvaluedollarcnt) # using plt direclty
# Out:
# <Container object of 17 artists>

# %% [markdown]
# Plotting is a very problem-specific task. I encourage you to play around with plots and use Google to figure out how to plot various plots in matplotlib for Python. There are tons of adjustments you can make: labels, hashmarks, titles, colors, thickness of lines, transparency, etc...
#
# Try to go through their tutorial [here](https://matplotlib.org/users/pyplot_tutorial.html).

# %% [markdown]
# # Merging datasets

# %% [markdown]
# Read in the second file, train_2016_v2.csv.

# %%
df2 = pd.read_csv('./data/Zillow/train_2016_v2.csv')

# %%
df.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  17073783                    NaN                       NaN           NaN
# 1  17088994                    NaN                       NaN           NaN
# 2  17100444                    NaN                       NaN           NaN
# 3  17102429                    NaN                       NaN           NaN
# 4  17109604                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          2.5         3.0                  NaN                    NaN
# 1          1.0         2.0                  NaN                    NaN
# 2          2.0         3.0                  NaN                    NaN
# 3          1.5         2.0                  NaN                    NaN
# 4          2.5         4.0                  NaN                    NaN
#
#    calculatedbathnbr  decktypeid         ...           numberofstories  \
# 0                2.5         NaN         ...                       2.0
# 1                1.0         NaN         ...                       1.0
# 2                2.0         NaN         ...                       1.0
# 3                1.5         NaN         ...                       1.0
# 4                2.5         NaN         ...                       2.0
#
#    fireplaceflag  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 0            NaN                    115087.0           191811.0
# 1            NaN                    143809.0           239679.0
# 2            NaN                     33619.0            47853.0
# 3            NaN                     45609.0            62914.0
# 4            NaN                    277000.0           554000.0
#
#    assessmentyear  landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# 0          2015.0                76724.0    2015.06                 NaN
# 1          2015.0                95870.0    2581.30                 NaN
# 2          2015.0                14234.0     591.64                 NaN
# 3          2015.0                17305.0     682.78                 NaN
# 4          2015.0               277000.0    5886.92                 NaN
#
#    taxdelinquencyyear  censustractandblock
# 0                 NaN         6.111002e+13
# 1                 NaN         6.111002e+13
# 2                 NaN         6.111001e+13
# 3                 NaN         6.111001e+13
# 4                 NaN         6.111001e+13
#
# [5 rows x 58 columns]

# %%
len(df2)
# Out:
# 90150

# %%
len(df2.parcelid.unique())
# Out:
# 90150

# %%
df2 = df2.groupby('parcelid')['logerror', 'transactiondate'].last()
df2.reset_index(inplace = True)

# %%
df2.head()
# Out:
#    parcelid  logerror transactiondate
# 0  11016594    0.0276      2016-01-01
# 1  14366692   -0.1684      2016-01-01
# 2  12098116   -0.0040      2016-01-01
# 3  12643413    0.0218      2016-01-02
# 4  14432541   -0.0050      2016-01-02

# %% [markdown]
# Let's merge on the column `parcelid`, since it uniquely identifies the rows.

# %%
df3 = df.merge(df2, how = 'left', on = 'parcelid') # this is the shortest way to do it

# %%
df4 = df.merge(df2, how = 'left', left_on = 'parcelid', right_on = 'parcelid') # this also works
# you may need left_on and right_on if the identifying columns are named differently

# %%
df3.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  17073783                    NaN                       NaN           NaN
# 1  17088994                    NaN                       NaN           NaN
# 2  17100444                    NaN                       NaN           NaN
# 3  17102429                    NaN                       NaN           NaN
# 4  17109604                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          2.5         3.0                  NaN                    NaN
# 1          1.0         2.0                  NaN                    NaN
# 2          2.0         3.0                  NaN                    NaN
# 3          1.5         2.0                  NaN                    NaN
# 4          2.5         4.0                  NaN                    NaN
#
#    calculatedbathnbr  decktypeid       ...         structuretaxvaluedollarcnt  \
# 0                2.5         NaN       ...                           115087.0
# 1                1.0         NaN       ...                           143809.0
# 2                2.0         NaN       ...                            33619.0
# 3                1.5         NaN       ...                            45609.0
# 4                2.5         NaN       ...                           277000.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0           191811.0          2015.0                76724.0    2015.06
# 1           239679.0          2015.0                95870.0    2581.30
# 2            47853.0          2015.0                14234.0     591.64
# 3            62914.0          2015.0                17305.0     682.78
# 4           554000.0          2015.0               277000.0    5886.92
#
#    taxdelinquencyflag  taxdelinquencyyear  censustractandblock  logerror  \
# 0                 NaN                 NaN         6.111002e+13    0.0953
# 1                 NaN                 NaN         6.111002e+13    0.0198
# 2                 NaN                 NaN         6.111001e+13    0.0060
# 3                 NaN                 NaN         6.111001e+13   -0.0566
# 4                 NaN                 NaN         6.111001e+13    0.0573
#
#    transactiondate
# 0       2016-01-27
# 1       2016-03-30
# 2       2016-05-27
# 3       2016-06-07
# 4       2016-08-08
#
# [5 rows x 60 columns]

# %%
# del df4 # gets rid of df4 from memory

# %% [markdown]
# Let's compute the difference from the average assessed value by cohort year.
#
# 1. We need to compute the average value by cohort year.
# 2. We need to merge this back in to the big dataset.
# 3. We need to compute the difference in a new column.

# %%
temp = df3.groupby('yearbuilt')['taxvaluedollarcnt'].mean().reset_index() # what does this syntax say?
temp.head()
# Out:
#    yearbuilt  taxvaluedollarcnt
# 0     1885.0      295624.000000
# 1     1886.0       31370.000000
# 2     1887.0      287200.000000
# 3     1888.0      669325.500000
# 4     1890.0      322564.666667

# %%
#1 compute cohort value average
temp = df3.groupby('yearbuilt')['taxvaluedollarcnt'].mean().reset_index() # what does this syntax say?
temp.rename(columns = {'taxvaluedollarcnt': 'cohort_mean_value'}, inplace= True) # this is an example of renaming the column usinga a dictionary 
# Why did we rename the column? 
temp.head()
# Out:
#    yearbuilt  cohort_mean_value
# 0     1885.0      295624.000000
# 1     1886.0       31370.000000
# 2     1887.0      287200.000000
# 3     1888.0      669325.500000
# 4     1890.0      322564.666667

# %%
#2 merge back in to df3
df3 = df3.merge(temp, how = 'left', on = 'yearbuilt')

# %%
df3.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  17073783                    NaN                       NaN           NaN
# 1  17088994                    NaN                       NaN           NaN
# 2  17100444                    NaN                       NaN           NaN
# 3  17102429                    NaN                       NaN           NaN
# 4  17109604                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          2.5         3.0                  NaN                    NaN
# 1          1.0         2.0                  NaN                    NaN
# 2          2.0         3.0                  NaN                    NaN
# 3          1.5         2.0                  NaN                    NaN
# 4          2.5         4.0                  NaN                    NaN
#
#    calculatedbathnbr  decktypeid        ...          taxvaluedollarcnt  \
# 0                2.5         NaN        ...                   191811.0
# 1                1.0         NaN        ...                   239679.0
# 2                2.0         NaN        ...                    47853.0
# 3                1.5         NaN        ...                    62914.0
# 4                2.5         NaN        ...                   554000.0
#
#    assessmentyear  landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# 0          2015.0                76724.0    2015.06                 NaN
# 1          2015.0                95870.0    2581.30                 NaN
# 2          2015.0                14234.0     591.64                 NaN
# 3          2015.0                17305.0     682.78                 NaN
# 4          2015.0               277000.0    5886.92                 NaN
#
#    taxdelinquencyyear  censustractandblock  logerror  transactiondate  \
# 0                 NaN         6.111002e+13    0.0953       2016-01-27
# 1                 NaN         6.111002e+13    0.0198       2016-03-30
# 2                 NaN         6.111001e+13    0.0060       2016-05-27
# 3                 NaN         6.111001e+13   -0.0566       2016-06-07
# 4                 NaN         6.111001e+13    0.0573       2016-08-08
#
#    cohort_mean_value
# 0      398743.962126
# 1      496813.620988
# 2      350189.434091
# 3      413321.663216
# 4      347639.973479
#
# [5 rows x 61 columns]

# %%
df3['delta_value'] = df3.taxvaluedollarcnt-df3.cohort_mean_value
df3.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  17073783                    NaN                       NaN           NaN
# 1  17088994                    NaN                       NaN           NaN
# 2  17100444                    NaN                       NaN           NaN
# 3  17102429                    NaN                       NaN           NaN
# 4  17109604                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          2.5         3.0                  NaN                    NaN
# 1          1.0         2.0                  NaN                    NaN
# 2          2.0         3.0                  NaN                    NaN
# 3          1.5         2.0                  NaN                    NaN
# 4          2.5         4.0                  NaN                    NaN
#
#    calculatedbathnbr  decktypeid      ...        assessmentyear  \
# 0                2.5         NaN      ...                2015.0
# 1                1.0         NaN      ...                2015.0
# 2                2.0         NaN      ...                2015.0
# 3                1.5         NaN      ...                2015.0
# 4                2.5         NaN      ...                2015.0
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  taxdelinquencyyear  \
# 0                76724.0    2015.06                 NaN                 NaN
# 1                95870.0    2581.30                 NaN                 NaN
# 2                14234.0     591.64                 NaN                 NaN
# 3                17305.0     682.78                 NaN                 NaN
# 4               277000.0    5886.92                 NaN                 NaN
#
#    censustractandblock  logerror  transactiondate  cohort_mean_value  \
# 0         6.111002e+13    0.0953       2016-01-27      398743.962126
# 1         6.111002e+13    0.0198       2016-03-30      496813.620988
# 2         6.111001e+13    0.0060       2016-05-27      350189.434091
# 3         6.111001e+13   -0.0566       2016-06-07      413321.663216
# 4         6.111001e+13    0.0573       2016-08-08      347639.973479
#
#      delta_value
# 0 -206932.962126
# 1 -257134.620988
# 2 -302336.434091
# 3 -350407.663216
# 4  206360.026521
#
# [5 rows x 62 columns]

# %% [markdown]
# # Run a regression
#
# For the cohort year 2010, run the regression:
# $$
# \text{Value}=\beta_0+\beta_1\text{bdrms}+\beta_2\text{sqft}
# $$

# %%
temp = df[df.yearbuilt==2010]

# %%
import statsmodels.formula.api as smf # import statsmodels formula api
res = smf.ols(formula='taxvaluedollarcnt ~ bedroomcnt + calculatedfinishedsquarefeet', data=temp).fit()

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      taxvaluedollarcnt   R-squared:                       0.598
# Model:                            OLS   Adj. R-squared:                  0.596
# Method:                 Least Squares   F-statistic:                     249.2
# Date:                Thu, 14 Sep 2017   Prob (F-statistic):           5.00e-67
# Time:                        21:19:31   Log-Likelihood:                -5045.3
# No. Observations:                 338   AIC:                         1.010e+04
# Df Residuals:                     335   BIC:                         1.011e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                     1.499e+05   1.14e+05      1.312      0.191   -7.49e+04    3.75e+05
# bedroomcnt                   -3.098e+05   4.34e+04     -7.135      0.000   -3.95e+05   -2.24e+05
# calculatedfinishedsquarefeet   778.0480     36.824     21.129      0.000     705.612     850.484
# ==============================================================================
# Omnibus:                      384.944   Durbin-Watson:                   2.239
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            34068.153
# Skew:                           4.814   Prob(JB):                         0.00
# Kurtosis:                      51.232   Cond. No.                     7.68e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.68e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
res.params
# Out:
# Intercept                       149861.532649
# bedroomcnt                     -309844.598954
# calculatedfinishedsquarefeet       778.047959
# dtype: float64

# %%
res.params['bedroomcnt'] # reference a particular parameter
# Out:
# -309844.59895397665

# %%
res.rsquared # reference r^2
# Out:
# 0.59804898933137185

# %% [markdown]
# What about factor variables? Let's treat bedroom as as a factor variable

# %%
res = smf.ols(formula='taxvaluedollarcnt ~ C(bedroomcnt) + calculatedfinishedsquarefeet', data=temp).fit()

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      taxvaluedollarcnt   R-squared:                       0.627
# Model:                            OLS   Adj. R-squared:                  0.615
# Method:                 Least Squares   F-statistic:                     54.92
# Date:                Thu, 14 Sep 2017   Prob (F-statistic):           5.10e-64
# Time:                        21:23:52   Log-Likelihood:                -5032.8
# No. Observations:                 338   AIC:                         1.009e+04
# Df Residuals:                     327   BIC:                         1.013e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                    -1.902e+06   5.41e+05     -3.514      0.001   -2.97e+06   -8.37e+05
# C(bedroomcnt)[T.1.0]          1.671e+06   5.86e+05      2.851      0.005    5.18e+05    2.82e+06
# C(bedroomcnt)[T.2.0]          1.383e+06   5.29e+05      2.613      0.009    3.42e+05    2.42e+06
# C(bedroomcnt)[T.3.0]          1.046e+06   5.24e+05      1.998      0.047    1.61e+04    2.08e+06
# C(bedroomcnt)[T.4.0]          6.403e+05   5.22e+05      1.228      0.220   -3.86e+05    1.67e+06
# C(bedroomcnt)[T.5.0]         -1.283e+05   5.39e+05     -0.238      0.812   -1.19e+06    9.31e+05
# C(bedroomcnt)[T.6.0]         -4.225e+05   6.27e+05     -0.674      0.501   -1.66e+06     8.1e+05
# C(bedroomcnt)[T.7.0]          8.414e+05   8.97e+05      0.938      0.349   -9.24e+05    2.61e+06
# C(bedroomcnt)[T.8.0]         -8.173e+05   6.29e+05     -1.300      0.195   -2.05e+06     4.2e+05
# C(bedroomcnt)[T.9.0]         -3.734e+05   8.84e+05     -0.423      0.673   -2.11e+06    1.36e+06
# calculatedfinishedsquarefeet   838.8621     40.866     20.527      0.000     758.469     919.255
# ==============================================================================
# Omnibus:                      387.207   Durbin-Watson:                   2.261
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            35519.744
# Skew:                           4.849   Prob(JB):                         0.00
# Kurtosis:                      52.275   Cond. No.                     1.10e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.1e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
res.params
# Out:
# Intercept                      -1.901744e+06
# C(bedroomcnt)[T.1]              1.671185e+06
# C(bedroomcnt)[T.2]              1.382935e+06
# C(bedroomcnt)[T.3]              1.046424e+06
# C(bedroomcnt)[T.4]              6.402855e+05
# C(bedroomcnt)[T.5]             -1.283105e+05
# C(bedroomcnt)[T.6]             -4.224662e+05
# C(bedroomcnt)[T.7]              8.413999e+05
# C(bedroomcnt)[T.8]             -8.172926e+05
# C(bedroomcnt)[T.9]             -3.734477e+05
# calculatedfinishedsquarefeet    8.388621e+02
# dtype: float64

# %%
res.rsquared
# Out:
# 0.62679876253701017

# %%
res.params['C(bedroomcnt)[T.9]'] # reference a level of bedroom (=9 bedroom)
# Out:
# -373447.74095878308
